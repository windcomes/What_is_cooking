# %%
x1 = [i for i in range(2,16)]
x2 = [j for j in range(2,16)]
y1 = [0.007131697440911998, 0.008606635624895758, 0.009764825539582859, 0.010591112200330757,
0.011325991036490547, 0.011942534340045647, 0.012526253376980424, 
0.013006556212771544, 0.01346698989628855, 0.013883938841373131, 
0.014288692093094288, 0.01465999788304746, 0.014978458709157953, 0.01532260705484092]
y2 = [0.004094331133762447, 0.0037919017631573852, 0.0036439587261920163, 
      0.003504384388438185, 0.003378640441902875, 0.003300361321642747, 
      0.0032332517759763937, 0.0031702974430629503, 0.0031229662678574164, 
      0.0030781321700605315, 0.0030374024526892266, 0.0030137458172677474, 
      0.0029747485276760237, 0.0029618565618484663]
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.ylabel("Mean absolute error")
plt.xlabel("Number of ingredients in a partial recipe")
line1 = plt.plot(x1,y1,color = 'orange',marker ='.')
line2 = plt.plot(x2,y2,color = 'red',marker = '.')
plt.legend(('Binary','TD-IDF'))
plt.show()
